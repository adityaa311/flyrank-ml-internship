# %% [markdown]
# <a href="https://colab.research.google.com/github/adityaa311/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/adityaa311/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# ## My Lane
#
# I selected the Content Refresh lane because it focuses on identifying web pages that are losing search performance. This project can help content teams decide which pages should be updated first to improve search visibility and organic traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ## The Question
#
# **Decision:** Which content pages should be refreshed first?
#
# **Action:** Prioritize pages predicted to decline so the SEO team can update them before rankings fall further.
#
# **Cost of a wrong decision:** Refreshing the wrong pages wastes time and resources, while missing declining pages may lead to traffic and ranking losses.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains multiple clients, hundreds of thousands of content pages, and daily search performance data. These numbers show that manual analysis would be difficult, making this a good problem for data analysis and machine learning.

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("/content/content_refresh_anonymized.csv")

# Show 2–3 real numbers
print("Total rows:", len(df))
print("Total columns:", len(df.columns))
print("Trend distribution:")
print(df["trend_direction"].value_counts())
# Out:
# Total rows: 30000
# Total columns: 44
# Trend distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# The analysis can identify patterns that are associated with declining search performance, but it cannot prove that one factor directly causes another. The results should be used to support decisions together with human expertise.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
